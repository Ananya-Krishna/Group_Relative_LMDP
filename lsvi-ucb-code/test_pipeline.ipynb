# %%
import numpy as np 
from lincomblock import LinCombLock, MisLinCombLock
import agent as agent 
from server_experiment import Run_experiment, Tune_RLSVI, Tune_UCB, Run_UCB_experiment


S = 100
A = 5
H = 10
dim = 10
num_epi = 3000
num_trial = 10

mis_prob = 0.05

# Run_experiment(num_state=S, num_action=A, horizon=H, dimension=dim, num_epi=num_epi, num_trial=num_trial, mis_prob = mis_prob, exp_id=1)


# Tune_RLSVI(num_state=S, num_action=A, horizon=H, dimension=dim, num_epi=num_epi, num_trial=num_trial, mis_prob = mis_prob, tune_lambda = False)

# Tune_RLSVI(num_state=S, num_action=A, horizon=H, dimension=dim, num_epi=num_epi, num_trial=num_trial, mis_prob = 0, tune_lambda = False)

# Tune_UCB(num_state=S, num_action=A, horizon=H, dimension=dim, num_epi=num_epi, num_trial=num_trial, mis_prob = 0)

# Tune_UCB(num_state=S, num_action=A, horizon=H, dimension=dim, num_epi=num_epi, num_trial=num_trial, mis_prob = 0.05)


Run_UCB_experiment(num_state=S, num_action=A, horizon=H, dimension=dim, num_epi=num_epi, num_trial=num_trial, mis_prob = 0.05, exp_id=1)
# Out:
# (10, 100, 5, 100)
# Trial: 1
# beta in LSVI_UCB: 0.5
# we have finished 0 episodes of LSVI-UCB
# we have finished 1000 episodes of LSVI-UCB
# we have finished 2000 episodes of LSVI-UCB
# average_reward of UCB is 0.5734628236234175
# average_reward of optimal policy is 0.5868034368741523
# Total run time: 274.6545737090055
# Trial: 2
# beta in LSVI_UCB: 0.5
# we have finished 0 episodes of LSVI-UCB
# we have finished 1000 episodes of LSVI-UCB
# we have finished 2000 episodes of LSVI-UCB
# average_reward of UCB is 0.5854824750763082
# average_reward of optimal policy is 0.5741511806409006
# Total run time: 277.26263545799884
# Trial: 3
# beta in LSVI_UCB: 0.5
# we have finished 0 episodes of LSVI-UCB
# we have finished 1000 episodes of LSVI-UCB
# we have finished 2000 episodes of LSVI-UCB
# average_reward of UCB is 0.5668221006613755
# average_reward of optimal policy is 0.5674871648944525
# Total run time: 274.2758895830193
# Trial: 4
# beta in LSVI_UCB: 0.5
# ...

# %%
S_seq = [100, 200, 400]
mis_seq = [0, 0.05]
for S in S_seq:
    for mis_prob in mis_seq: 
        print('s: '+str(S) + ' misspecification: ' + str(mis_prob) )
        # print('RLSVI')
        # Tune_RLSVI(num_state=S, num_action=A, horizon=H, dimension=dim, num_epi=num_epi, num_trial=num_trial, mis_prob = mis_prob, tune_lambda = False)

        print('LSVI-UCB')
        Tune_UCB(num_state=S, num_action=A, horizon=H, dimension=dim, num_epi=num_epi, num_trial=num_trial, mis_prob = mis_prob)
# Out:
# s: 100 misspecification: 0
# LSVI-UCB
# (10, 100, 5, 100)
# Trial: 1
# beta in LSVI_UCB: 0.2
# we have finished 0 episodes of LSVI-UCB
# we have finished 1000 episodes of LSVI-UCB
# beta in LSVI_UCB: 0.3
# we have finished 0 episodes of LSVI-UCB
# we have finished 1000 episodes of LSVI-UCB
# beta in LSVI_UCB: 0.4
# we have finished 0 episodes of LSVI-UCB
# we have finished 1000 episodes of LSVI-UCB
# beta in LSVI_UCB: 0.5
# we have finished 0 episodes of LSVI-UCB
# we have finished 1000 episodes of LSVI-UCB
# beta in LSVI_UCB: 0.6
# we have finished 0 episodes of LSVI-UCB
# we have finished 1000 episodes of LSVI-UCB
# beta in LSVI_UCB: 0.7
# we have finished 0 episodes of LSVI-UCB
# we have finished 1000 episodes of LSVI-UCB
# beta in LSVI_UCB: 0.8
# we have finished 0 episodes of LSVI-UCB
# we have finished 1000 episodes of LSVI-UCB
# average_reward of UCB  with beta =0.2 0.9007890504685705
# average_reward of UCB  with beta =0.3 0.9081196124121266
# ...
