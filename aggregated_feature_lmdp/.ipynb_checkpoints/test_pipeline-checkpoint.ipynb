# %%
import numpy as np 
from lincomblock import LinCombLock 
import agent as agent 
from experiment import Run_experiment


S = 1000
A = 5
H = 10
dim = 10
num_epi = 2000
num_trial = 2 

mis_prob = 0.1

Run_experiment(num_state=S, num_action=A, horizon=H, dimension=dim, num_epi=num_epi, num_trial=num_trial, mis_prob = mis_prob)
# Out:
# (5, 10, 5, 10)
# Trial: 1
# we have finished0 episodes of LSVI-eps-greedy
# beta in LSVI_UCB: 0.3
# we have finished 0 episodes of LSVI-UCB
# average_reward of UCB is 0.9390355748341571
# average_reward of eps_greedy is 0.0009435670935292539
# average_reward of optimal policy is 0.966014889426627
# Total run time: 43.640630822
# Trial: 2
# we have finished0 episodes of LSVI-eps-greedy
# beta in LSVI_UCB: 0.3
# we have finished 0 episodes of LSVI-UCB
# average_reward of UCB is 0.9420370326191749
# average_reward of eps_greedy is 0.7781248442242682
# average_reward of optimal policy is 0.964023607749761
# Total run time: 42.66722955
# size of raw-data is (2, 5000)
# file name is result_s10_a5_h5_d5.npz
# [ 0.46455749  1.42879687  1.39381612  2.3579454   2.32296465  3.28708297
#   3.25210222  4.21622519  4.18124444  5.14537372  5.11039296  6.07451759
#   6.03953684  6.50409898  6.46911823  6.43413747  6.39915672  6.36417597
# ...

# %%
# plot the figures
